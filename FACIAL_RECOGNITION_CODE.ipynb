# %%
import mediapipe as mp 
import cv2

# %%
# !pip install mediapipe opencv-python pandas scikit-learn
# Out:
# ^C

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %% [markdown]
# # 1. Make Detections

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %%
results.face_landmarks.landmark[0]

# %% [markdown]
# ### POSE LANDMARKS
#     <img src = "https://i.imgur.com/AzKNp7A.png">

# %% [markdown]
# ### HAND LANDMARKS
#     <img src = "https://media.geeksforgeeks.org/wp-content/uploads/20210802154942/HandLandmarks.png">

# %% [markdown]
# # Capture Landmark & Export to csv

# %%
import csv
import os
import numpy as np

# %%
# num_cords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
# num_cords
# Out:
# 501

# %%
# landmarks = ['class']
# for val in range(1, num_cords+1):
#     landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
# ...

# %%
# with open('coordinates.csv', mode='w', newline='') as f:   # MAKING A NEW FILE WITH THW COMMAND "WITH", mode= write,  THE FILE CAN BE TOGGLED WITH THE KEY WORD "F"
#     csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL) #DELIMETER= char theat identifes the beg. or the end of the str
#     csv_writer.writerow(landmarks)   #write row = method

# %% [markdown]
# # making classes

# %%
# class_name = "think"

# %%
# to capture the co-ordiantes and save them in csv file 


# cap = cv2.VideoCapture(0)
#  #. Initiate holistic model
# with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
#     while cap.isOpened():
#         ret, frame = cap.read()
        
#         # Recolor Feed
#         image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#         image.flags.writeable = False        
        
#         # Make Detections
#         results = holistic.process(image)
#         # print(results.face_landmarks)
        
#         # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
#         # Recolor image back to BGR for rendering
#         image.flags.writeable = True   
#         image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
#         # 1. Draw face landmarks
#         mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
#                                  mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
#                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
#                                  )
        
#         # 2. Right hand
#         mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
#                                  mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
#                                  )

#         # 3. Left Hand
#         mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
#                                  mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
#                                  )

#         # 4. Pose Detections
#         mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
#                                  mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
#                                  )
        
#         # export co ordinates 
#         try:
#             # Extract Pose landmarks                                           flatten() function we can flatten a matrix to one dimension in python
#             pose = results.pose_landmarks.landmark
#             pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
#             # Extract Face landmarks
#             face = results.face_landmarks.landmark
#             face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
#             # Concate rows
#             row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('think.csv', mode='a', newline='') as f:     #mode = append
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row)
                
#         except:
#              pass
                        
#         cv2.imshow('Raw Webcam Feed', image)

#         if cv2.waitKey(10) & 0xFF == ord('q'):
#             break

# cap.release()
# cv2.destroyAllWindows()

# %% [markdown]
# # 3. Train Model Using Skit Learn

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coordinates.csv')

# %%
df.head()
# Out:
#    class        x1        y1        z1        v1        x2        y2  \
# 0  happy  0.480442  0.417201 -0.931047  0.999701  0.508284  0.354946
# 1  happy  0.483823  0.417125 -1.046853  0.999681  0.511749  0.354462
# 2  happy  0.484023  0.412030 -1.031840  0.999661  0.511910  0.349847
# 3  happy  0.482657  0.405745 -1.017945  0.999656  0.510690  0.344477
# 4  happy  0.482638  0.405942 -1.010210  0.999669  0.510656  0.344464
#
#          z2        v2        x3  ...      z499  v499      x500      y500  \
# 0 -0.891668  0.999397  0.526673  ... -0.005180     0  0.555340  0.348864
# 1 -0.990704  0.999358  0.529856  ... -0.007335     0  0.550507  0.353582
# 2 -0.976662  0.999319  0.529992  ... -0.007183     0  0.544092  0.346220
# 3 -0.965380  0.999298  0.528873  ... -0.006611     0  0.537778  0.342930
# 4 -0.958568  0.999323  0.528848  ... -0.008086     0  0.539779  0.352040
#
#        z500  v500      x501      y501      z501  v501
# 0  0.007841     0  0.560231  0.343780  0.007924     0
# ...

# %%
df.tail()
# Out:
#        class        x1        y1        z1        v1        x2        y2  \
# 268  victory  0.516809  0.436833 -0.804967  0.999981  0.541637  0.381531
# 269  victory  0.516889  0.436655 -0.805451  0.999980  0.542029  0.381546
# 270  victory  0.517035  0.436065 -0.804406  0.999980  0.542812  0.381451
# 271  victory  0.517144  0.436037 -0.805683  0.999980  0.543342  0.381500
# 272  victory  0.517154  0.436000 -0.804626  0.999980  0.543377  0.381604
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# 268 -0.749221  0.999965  0.560806  ... -0.008058     0  0.587966  0.382533
# 269 -0.750238  0.999963  0.561174  ... -0.008744     0  0.588829  0.382848
# 270 -0.749167  0.999962  0.561945  ... -0.008860     0  0.588613  0.386295
# 271 -0.750299  0.999961  0.562521  ... -0.008357     0  0.588859  0.385196
# 272 -0.750417  0.999961  0.562559  ... -0.008241     0  0.587851  0.384121
#
#          z500  v500      x501      y501      z501  v501
# ...

# %%
X = df.drop('class', axis=1) # features (x,y,v,z)
y = df['class'] # target value (is always on the y axis )

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=1234) #randoms_state = controls the shuffling process

# %% [markdown]
# # Train ML Classification Model

# %%
from sklearn.pipeline import make_pipeline            # Construct a Pipeline from the given estimators 
from sklearn.preprocessing import StandardScaler      # Standardize features by removing the mean and scaling to unit variance  

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier # all 4 are ml models

# %%
pipelines = {                                                          #make_pipeline(StandardScaler()) = Construct a Pipeline from the given estimators.
    #'lr':make_pipeline(StandardScaler(), LogisticRegression()),        notnusing because of over fitting
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
list(pipelines.values())[1]     #shows the pipeline wihich is built
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model

# %%
model.score(X_train, y_train) #over fitting model
# Out:
# 1.0

# %%
fit_models['rf'].predict(X_train)
# Out:
# array(['victory', 'think', 'happy', 'sad', 'victory', 'sad', 'sad',
#        'happy', 'happy', 'happy', 'sad', 'victory', 'victory', 'sad',
#        'sad', 'think', 'happy', 'victory', 'sad', 'sad', 'happy', 'sad',
#        'happy', 'happy', 'victory', 'think', 'victory', 'victory',
#        'victory', 'sad', 'happy', 'victory', 'think', 'victory', 'sad',
#        'happy', 'think', 'sad', 'sad', 'sad', 'sad', 'sad', 'happy',
#        'sad', 'victory', 'happy', 'think', 'sad', 'sad', 'happy',
#        'victory', 'sad', 'sad', 'happy', 'happy', 'happy', 'victory',
#        'victory', 'think', 'sad', 'think', 'sad', 'victory', 'sad',
#        'happy', 'sad', 'victory', 'victory', 'sad', 'happy', 'victory',
#        'happy', 'sad', 'sad', 'think', 'sad', 'think', 'sad', 'happy',
#        'happy', 'happy', 'sad', 'sad', 'sad', 'sad', 'think', 'victory',
#        'sad', 'sad', 'happy', 'sad', 'sad', 'sad', 'think', 'victory',
# ...

# %% [markdown]
# # 3.3 Evaluate and Serialize Model

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle    # is used to save a model

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))  #yhat = used to store the actual prediction values
# Out:
# rc 1.0
# rf 1.0
# gb 1.0

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['sad', 'sad', 'sad', 'happy', 'victory', 'sad', 'sad', 'happy',
#        'sad', 'think', 'think', 'sad', 'victory', 'sad', 'happy', 'sad',
#        'sad', 'sad', 'sad', 'think', 'sad', 'happy', 'victory', 'victory',
#        'think', 'happy', 'happy', 'sad', 'happy', 'sad', 'victory', 'sad',
#        'happy', 'happy', 'victory', 'sad', 'victory', 'think', 'victory',
#        'happy', 'happy', 'think', 'victory', 'sad', 'sad', 'think',
#        'victory', 'happy', 'happy', 'happy', 'happy', 'think', 'victory',
#        'sad', 'sad', 'happy', 'think', 'victory', 'think', 'happy', 'sad',
#        'think', 'sad', 'sad', 'victory', 'victory', 'happy', 'sad',
#        'happy', 'sad', 'sad', 'happy', 'sad', 'happy', 'happy', 'sad',
#        'think', 'think', 'think', 'happy', 'sad', 'sad', 'victory',
#        'think', 'happy', 'sad', 'sad', 'happy', 'victory', 'sad', 'think',
#        'victory', 'victory', 'happy', 'victory', 'sad', 'think',
# ...

# %%
y_test
# Out:
# 101        sad
# 157        sad
# 73         sad
# 6        happy
# 239    victory
#         ...
# 153        sad
# 245    victory
# 8        happy
# 228    victory
# 117        sad
# Name: class, Length: 137, dtype: object

# %%
with open('body_language_gb.pkl', 'wb') as f:   # exported the model using the pickle in wb = write binary mode
    pickle.dump(fit_models['gb'], f)

# %% [markdown]
# #  Make Detections with Model

# %%
with open('body_language_gb.pkl', 'rb') as f:    #imported the model using pickle in rb = read binary mode
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingclassifier', GradientBoostingClassifier())])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('cords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

 # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]     #predicting the class
            body_language_prob = model.predict_proba(X)[0] #predicting the probablity of that clause 
            print(body_language_class, body_language_prob)
            
            #Grab ear coords
            cords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
           # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# think [4.12616635e-04 2.81081954e-02 9.71447142e-01 3.20460933e-05]
# think [4.12828257e-04 2.81081894e-02 9.71446936e-01 3.20467069e-05]
# think [1.10932927e-05 2.81164017e-02 9.71867272e-01 5.23257600e-06]
# think [1.10933083e-05 2.81150365e-02 9.71868639e-01 5.23098925e-06]
# think [3.61102775e-05 5.84227239e-02 9.41261872e-01 2.79293910e-04]
# sad [4.03844209e-06 7.05016544e-01 2.90383620e-01 4.59579767e-03]
# sad [4.21782231e-06 7.35656786e-01 2.60821063e-01 3.51793244e-03]
# sad [3.82389129e-05 9.63169841e-01 2.12788242e-02 1.55130962e-02]
# sad [0.0111173  0.89512312 0.06694793 0.02681165]
# sad [0.00068143 0.60509504 0.39084958 0.00337395]
# sad [1.72426918e-03 9.92518447e-01 9.22693049e-04 4.83459045e-03]
# sad [2.00355699e-03 9.92596258e-01 5.65215287e-04 4.83496947e-03]
# sad [9.57934992e-05 9.65456802e-01 5.52951939e-03 2.89178850e-02]
# sad [1.36738942e-05 6.01249909e-01 3.94167969e-01 4.56844781e-03]
# sad [5.60607385e-05 5.66145210e-01 4.16756837e-01 1.70418921e-02]
# ...

# %%
tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640,480]).astype(int))
# Out:
# (508, 262)
